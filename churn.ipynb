# %%
import pandas as pd

# %%
df=pd.read_csv('churn-bigml-20.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df.tail()
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 662    WI             114        415                 No             Yes
# 663    AL             106        408                 No             Yes
# 664    VT              60        415                 No              No
# 665    WV             159        415                 No              No
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 662                     26              137.1               88
# 663                     29               83.6              131
# 664                      0              193.9              118
# 665                      0              169.8              114
# 666                      0              213.8              105
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
# ...

# %%
df.shape
# Out:
# (667, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.columns[0]
# Out:
# 'State'

# %% [markdown]
# df[df.columns[0]]=df.['state']

# %%
df.describe(include=['object','bool'])
# Out:
#        State International plan Voice mail plan  Churn
# count    667                667             667    667
# unique    51                  2               2      2
# top       AZ                 No              No  False
# freq      19                614             478    572

# %%
df['Churn']=df['Churn'].astype('int')

# %%
df['Churn'].value_counts()
# Out:
# 0    572
# 1     95
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# 0    0.857571
# 1    0.142429
# Name: Churn, dtype: float64

# %%
df.sort_values(by=['Number vmail messages','Total night minutes'],ascending=[False,False])
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 177    FL             144        415                 No             Yes
# 330    AR              63        510                 No             Yes
# 52     SD             144        408                 No             Yes
# 50     MO              64        510                 No             Yes
# 510    IN              81        408                 No             Yes
# ..    ...             ...        ...                ...             ...
# 576    PA             136        408                 No              No
# 179    MA             136        408                Yes              No
# 102    IL              87        510                 No              No
# 471    OH             135        415                 No              No
# 624    ND              27        415                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[df['Churn']==1]['Total day minutes'].mean()
# Out:
# 213.9915789473684

# %%
df[df['Churn']==0]['Total day minutes'].mean()
# Out:
# 175.46013986013986

# %%
df[(df['Churn']==0)&(df['International plan']=='No')]['Total night calls'].mean()
# Out:
# 100.17472118959108

# %%
df.iloc[:5,4]
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Voice mail plan, dtype: object

# %%
df.loc[:5,['International plan']]
# Out:
#   International plan
# 0                 No
# 1                 No
# 2                 No
# 3                 No
# 4                 No
# 5                 No

# %%
df.loc[:5,['International plan','Voice mail plan']]
# Out:
#   International plan Voice mail plan
# 0                 No              No
# 1                 No              No
# 2                 No              No
# 3                 No              No
# 4                 No              No
# 5                 No             Yes

# %%
df.iloc[-1]
# Out:
# State                        CT
# Account length              184
# Area code                   510
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         213.8
# Total day calls             105
# Total day charge          36.35
# Total eve minutes         159.6
# Total eve calls              84
# Total eve charge          13.57
# Total night minutes       139.2
# Total night calls           137
# Total night charge         6.26
# Total intl minutes          5.0
# Total intl calls             10
# Total intl charge          1.35
# Customer service calls        2
# Churn                         0
# Name: 666, dtype: object

# %%
df.iloc[-1:]
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 666    CT             184        510                Yes              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 666                      0              213.8              105
#
#      Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 666             36.35              159.6               84             13.57
#
#      Total night minutes  Total night calls  Total night charge  \
# 666                139.2                137                6.26
#
#      Total intl minutes  Total intl calls  Total intl charge  \
# 666                 5.0                10               1.35
#
#      Customer service calls  Churn
# 666                       2      0

# %%
import numpy as np

# %%
df.apply(np.max)
# Out:
# State                        WY
# Account length              232
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages        51
# Total day minutes         334.3
# Total day calls             165
# Total day charge          56.83
# Total eve minutes         361.8
# Total eve calls             168
# Total eve charge          30.75
# Total night minutes       367.7
# Total night calls           175
# Total night charge        16.55
# Total intl minutes         18.3
# Total intl calls             18
# Total intl charge          4.94
# Customer service calls        8
# Churn                         1
# dtype: object

# %%
df[df['State'].apply(lambda State:State[0]=='W')]
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 9      WI              68        415                 No              No
# 24     WA             127        408                 No              No
# 42     WY             215        510                 No              No
# 51     WA              83        415                 No              No
# 109    WI              69        510                Yes              No
# ..    ...             ...        ...                ...             ...
# 650    WY             148        408                 No              No
# 652    WA              84        415                 No              No
# 655    WI              87        415                 No              No
# 662    WI             114        415                 No             Yes
# 665    WV             159        415                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df[df['State'].apply(lambda State:State[0]=='S')]
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 3      SC             111        415                 No              No
# 48     SC              78        510                 No              No
# 52     SD             144        408                 No             Yes
# 55     SD             145        408                 No             Yes
# 70     SD              87        415                 No             Yes
# 86     SD              91        510                 No              No
# 99     SD             126        415                 No             Yes
# 135    SD              65        408                 No             Yes
# 175    SC              87        408                 No              No
# 227    SD              88        415                 No              No
# 290    SD              86        415                 No              No
# 301    SD              95        408                 No             Yes
# ...

# %%
dic={'Yes':True,'No':False}

# %%
df['International plan']=df['International plan'].map(dic)

# %%
df['International plan']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 662    False
# 663    False
# 664    False
# 665    False
# 666     True
# Name: International plan, Length: 667, dtype: bool

# %%
df.groupby(['Churn'])['Total eve minutes','Total day minutes','Total intl minutes'].describe()
# Out:
# C:\Users\AHMED\AppData\Local\Temp\ipykernel_11260\3133929302.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Churn'])['Total eve minutes','Total day minutes','Total intl minutes'].describe()
#       Total eve minutes                                                        \
#                   count        mean        std   min      25%    50%      75%
# Churn
# 0                 572.0  199.799650  48.172766  48.1  168.125  199.8  231.925
# 1                  95.0  224.764211  53.644848  88.1  193.950  219.4  260.500
#
#              Total day minutes              ...                 \
#          max             count        mean  ...     75%    max
# Churn                                       ...
# 0      361.8             572.0  175.460140  ...  212.25  315.6
# 1      350.5              95.0  213.991579  ...  270.50  334.3
#
#       Total intl minutes
# ...

# %%
df.groupby(['Churn'])['Total eve minutes','Total day minutes','Total intl minutes'].agg([np.max,np.min,np.std,np.mean])
# Out:
# C:\Users\AHMED\AppData\Local\Temp\ipykernel_11260\1197576807.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Churn'])['Total eve minutes','Total day minutes','Total intl minutes'].agg([np.max,np.min,np.std,np.mean])
#       Total eve minutes                              Total day minutes        \
#                    amax  amin        std        mean              amax  amin
# Churn
# 0                 361.8  48.1  48.172766  199.799650             315.6  25.9
# 1                 350.5  88.1  53.644848  224.764211             334.3  62.6
#
#                              Total intl minutes
#              std        mean               amax amin       std       mean
# Churn
# 0      50.527512  175.460140               18.0  0.0  2.804668  10.242657
# 1      70.962188  213.991579               18.3  2.0  2.841757  10.212632

# %%
pd.crosstab(df['Churn'],df['International plan'],normalize=True)
# Out:
# International plan     False     True
# Churn
# 0                   0.806597  0.050975
# 1                   0.113943  0.028486

# %%
print(df.columns)
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.pivot_table([ 'Total night calls','Total eve calls','Total day calls'],['Area code'],aggfunc='mean')
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408              99.390533       100.680473         100.952663
# 415             101.928783       100.074184          99.023739
# 510             100.484472       101.105590         101.515528

# %%
df['total']=df['Total intl charge'] + df['Total day minutes']

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
pd.crosstab(df['Churn'],df['International plan'],margins=True)
# Out:
# International plan  False  True  All
# Churn
# 0                     538    34  572
# 1                      76    19   95
# All                   614    53  667

# %%
sns.countplot(x="International plan",hue='Churn',data=df)
# Out:
# <Axes: xlabel='International plan', ylabel='count'>

# %%
pd.crosstab(df['Churn'],df['Customer service calls'],margins=True)
# Out:
# Customer service calls    0    1    2   3   4   5  6  7  8  All
# Churn
# 0                       129  213  126  74  21   6  1  1  1  572
# 1                        13   23   25   7  12  11  4  0  0   95
# All                     142  236  151  81  33  17  5  1  1  667

# %%
sns.countplot(x="Customer service calls",hue='Churn',data=df)
# Out:
# <Axes: xlabel='Customer service calls', ylabel='count'>

# %%
df['Many_csc']=(df['Churn']>3).astype('int')

# %%
df.head(
)
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    LA             117        408               False              No
# 1    IN              65        415               False              No
# 2    NY             161        415               False              No
# 3    SC             111        415               False              No
# 4    HI              49        510               False              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             31.37              351.6  ...                215.8
# ...

# %%
pd.crosstab(df['Churn'],df['Customer service calls'],margins=True)
# Out:
# Customer service calls    0    1    2   3   4   5  6  7  8  All
# Churn
# 0                       129  213  126  74  21   6  1  1  1  572
# 1                        13   23   25   7  12  11  4  0  0   95
# All                     142  236  151  81  33  17  5  1  1  667

# %%
pd.crosstab(df["Many_csc"]&df['International plan'],df['Churn'],margins=True)
# Out:
# Churn    0   1  All
# row_0
# False  572  95  667
# All    572  95  667

# %%
feature=['Total eve minutes','Total night minutes']

# %%
df[feature].hist()
# Out:
# array([[<Axes: title={'center': 'Total eve minutes'}>,
#         <Axes: title={'center': 'Total night minutes'}>]], dtype=object)

# %%
df[feature].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
df[feature].plot(kind='density',subplots=True)
# Out:
# array([<Axes: ylabel='Density'>, <Axes: ylabel='Density'>], dtype=object)

# %%
df[feature].plot(kind='density',subplots=True,layout=(1,2))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
df[feature].plot(kind='density',subplots=True,layout=(1,2),sharex=False)
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>]], dtype=object)

# %%
sns.displot(['Total eve minutes'])

# %%
sns.displot(df['Total eve minutes'])

# %%
plt.boxplot(df['Total eve minutes'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23529060690>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x235292aca50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23529278fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x235292ae090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x235292aea90>],
#  'means': []}

# %%
sns.boxplot(df['Total eve minutes'])
# Out:
# <Axes: >

# %%
sns.violinplot(df['Total eve minutes'])
# Out:
# <Axes: >
